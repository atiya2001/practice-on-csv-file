# %%
import pandas as pd
import numpy as np
import seaborn as sb
#import some libraries to be used

# %%
df = pd.read_csv('autos.csv')
#save the data on df

# %%
df.head(100)
#print some of data
# Out:
#     index          dateCrawled  \
# 0       0  2016-03-24 11:52:17
# 1       1  2016-03-24 10:58:45
# 2       2  2016-03-14 12:52:21
# 3       3  2016-03-17 16:54:04
# 4       4  2016-03-31 17:25:20
# ..    ...                  ...
# 95     95  2016-03-10 11:44:54
# 96     96  2016-03-28 16:37:43
# 97     97  2016-03-25 18:44:10
# 98     98  2016-03-31 10:53:10
# 99     99  2016-03-26 15:38:12
#
#                                                  name  seller offerType  \
# 0                                          Golf_3_1.6  privat   Angebot
# 1                                A5_Sportback_2.7_Tdi  privat   Angebot
# 2                      Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3                                  GOLF_4_1_4__3TÜRER  privat   Angebot
# 4                      Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# ..                                                ...     ...       ...
# 95                            Audi_A1_1.2_TFSI_S_Line  privat   Angebot
# ...

# %%
df.info()
#print all informations of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   index                371528 non-null  int64
#  1   dateCrawled          371528 non-null  object
#  2   name                 371528 non-null  object
#  3   seller               371528 non-null  object
#  4   offerType            371528 non-null  object
#  5   price                371528 non-null  int64
#  6   abtest               371528 non-null  object
#  7   vehicleType          333659 non-null  object
#  8   yearOfRegistration   371528 non-null  int64
#  9   gearbox              351319 non-null  object
#  10  powerPS              371528 non-null  int64
#  11  model                351044 non-null  object
#  12  kilometer            371528 non-null  int64
#  13  monthOfRegistration  371528 non-null  int64
#  14  fuelType             338142 non-null  object
# ...

# %%
max(df['price'])
#print the highest price of the car
# Out:
# 2147483647

# %%
df[df['price']==max(df['price'])]
#print informations of the highest car price
# Out:
#          index          dateCrawled                     name  seller  \
# 129969  129969  2016-03-11 08:37:57  Kaufe_AUTOS_Zum_basteln  privat
#
#        offerType       price abtest vehicleType  yearOfRegistration  gearbox  \
# 129969   Angebot  2147483647   test      andere                1996  manuell
#
#         ...  model kilometer  monthOfRegistration  fuelType           brand  \
# 129969  ...    NaN    150000                    1    andere  sonstige_autos
#
#        notRepairedDamage          dateCreated nrOfPictures  postalCode  \
# 129969                ja  2016-03-11 00:00:00            0        4720
#
#                    lastSeen
# 129969  2016-03-20 11:45:35
#
# [1 rows x 21 columns]

# %%
min(df['price'])
#print the lowest privce of the cars
# Out:
# 0

# %%
df[df['price']==0]
#print informations of the highest cars price
# Out:
#          index          dateCrawled  \
# 7            7  2016-03-21 18:54:38
# 40          40  2016-03-26 22:06:17
# 115        115  2016-03-19 18:40:12
# 119        119  2016-03-20 18:53:27
# 157        157  2016-03-11 18:55:53
# ...        ...                  ...
# 371356  371356  2016-03-09 15:56:30
# 371392  371392  2016-03-20 14:55:07
# 371402  371402  2016-03-24 13:48:05
# 371431  371431  2016-03-10 22:55:50
# 371522  371522  2016-03-21 09:50:58
#
#                                                     name  seller offerType  \
# 7                           VW_Derby_Bj_80__Scheunenfund  privat   Angebot
# 40                     Suche_Opel_corsa_a_zu_verschenken  privat   Angebot
# 115                                      Golf_IV_1.4_16V  privat   Angebot
# 119                       Polo_6n_Karosse_zu_verschenken  privat   Angebot
# 157               Opel_meriva_1.6_16_v_lpg__z16xe_no_OPC  privat   Angebot
# ...

# %%
sum(df['price']==0)
#print the number  of cars that are priceless
# Out:
# 10778

# %%
np.mean(df['price'])
#calculate the avarage price
# Out:
# 17295.14186548524

# %%
np.mean(df['kilometer'])
#calculate the avarage kilometer
# Out:
# 125618.68822807433

# %%
df[df['kilometer']==min(df['kilometer'])]
#print all car information which make the less kilometers
# Out:
#          index          dateCrawled  \
# 15          15  2016-03-11 21:39:15
# 28          28  2016-03-09 11:56:38
# 52          52  2016-04-04 10:57:36
# 115        115  2016-03-19 18:40:12
# 119        119  2016-03-20 18:53:27
# ...        ...                  ...
# 371222  371222  2016-03-31 13:39:54
# 371255  371255  2016-03-12 03:36:56
# 371288  371288  2016-03-11 16:54:01
# 371305  371305  2016-03-27 16:48:25
# 371321  371321  2016-03-12 19:49:38
#
#                                                      name  seller offerType  \
# 15                           KA_Lufthansa_Edition_450€_VB  privat   Angebot
# 28                                   Volkswagen_T3_andere  privat   Angebot
# 52          Verkaufe_meinen_kleinen_wegen_neu_Anschaffung  privat   Angebot
# 115                                       Golf_IV_1.4_16V  privat   Angebot
# 119                        Polo_6n_Karosse_zu_verschenken  privat   Angebot
# ...

# %%
df[df['kilometer']==max(df['kilometer'])]
#print all car information which make the largest kilometers
# Out:
#          index          dateCrawled  \
# 0            0  2016-03-24 11:52:17
# 3            3  2016-03-17 16:54:04
# 5            5  2016-04-04 17:36:23
# 6            6  2016-04-01 20:48:51
# 9            9  2016-03-17 10:53:50
# ...        ...                  ...
# 371520  371520  2016-03-19 19:53:49
# 371521  371521  2016-03-27 20:36:20
# 371522  371522  2016-03-21 09:50:58
# 371525  371525  2016-03-19 18:57:12
# 371526  371526  2016-03-20 19:41:08
#
#                                                      name  seller offerType  \
# 0                                              Golf_3_1.6  privat   Angebot
# 3                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# 6                             Peugeot_206_CC_110_Platinum  privat   Angebot
# 9       VW_Golf_4_5_tuerig_zu_verkaufen_mit_Anhaengerk...  privat   Angebot
# ...

# %%
df['brand'].value_counts()
#calculate how many cars are there of each brand
# Out:
# volkswagen        79640
# bmw               40274
# opel              40136
# mercedes_benz     35309
# audi              32873
# ford              25573
# renault           17969
# peugeot           11027
# fiat               9676
# seat               7022
# mazda              5695
# skoda              5641
# smart              5249
# citroen            5182
# nissan             5037
# toyota             4694
# sonstige_autos     3982
# hyundai            3646
# mini               3394
# volvo              3327
# mitsubishi         3061
# honda              2836
# kia                2555
# alfa_romeo         2345
# suzuki             2328
# porsche            2215
# chevrolet          1845
# chrysler           1452
# dacia               900
# jeep                807
# daihatsu            806
# subaru              779
# land_rover          770
# jaguar              621
# trabant             591
# daewoo              542
# saab                530
# rover               490
# ...

# %%
brand=df['brand'].unique()
brand
#create a list contain all the brands
# Out:
# array(['volkswagen', 'audi', 'jeep', 'skoda', 'bmw', 'peugeot', 'ford',
#        'mazda', 'nissan', 'renault', 'mercedes_benz', 'opel', 'seat',
#        'citroen', 'honda', 'fiat', 'mini', 'smart', 'hyundai',
#        'sonstige_autos', 'alfa_romeo', 'subaru', 'volvo', 'mitsubishi',
#        'kia', 'suzuki', 'lancia', 'porsche', 'toyota', 'chevrolet',
#        'dacia', 'daihatsu', 'trabant', 'saab', 'chrysler', 'jaguar',
#        'daewoo', 'rover', 'land_rover', 'lada'], dtype=object)

# %%
df['brand'].nunique()
#calculate the numbers of brands
# Out:
# 40

# %%
sb.countplot(x='fuelType',data=df)
# Out:
# <Axes: xlabel='fuelType', ylabel='count'>

# %%
sb.countplot(x='gearbox',data=df)
# Out:
# <Axes: xlabel='gearbox', ylabel='count'>
